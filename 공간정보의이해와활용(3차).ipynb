# %% [markdown]
# ![슬라이드1.PNG](data:image/png;base64,...)

# %% [markdown]
# #Part1 공간정보 이해
# ![슬라이드3.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 1. 공간정보

# %% [markdown]
# ### 자료와 정보
# ![슬라이드5.PNG](data:image/png;base64,...)
